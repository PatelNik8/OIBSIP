# %% [markdown]
# # Task 5: Sales Prediction using Python
#
# ## 1. Introduction
# ## 2. Dataset Overview
# ## 3. Data Cleaning
# ## 4. Exploratory Data Analysis
# ## 5. Feature Selection
# ## 6. Model Building
# ## 7. Model Evaluation
# ## 8. Conclusion
