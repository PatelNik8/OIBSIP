# %% [markdown]
# ## SMS Spam Dectection using ML

# %% [markdown]
# # Task 4: Email Spam Detection using Machine Learning
#
# ## 1. Introduction
# ## 2. Dataset Overview
# ## 3. Data Cleaning
# ## 4. Exploratory Data Analysis
# ## 5. Text Vectorization
# ## 6. Model Building
# ## 7. Model Evaluation
# ## 8. Conclusion
